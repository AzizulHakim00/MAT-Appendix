# %% [markdown]
# <a href="https://colab.research.google.com/github/AzizulHakim00/MAT-Appendix/blob/v32-locked-revalidation/MAT_Appendix_V32_Locked_Revalidation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MAT-Appendix V3.2 Locked Revalidation
#
# Final preregistered validation: 5 repeats × 5 outer folds, CatBoost vs GlobalBlend vs V32LockedBlend. No result-driven architecture changes. Outputs are displayed in Colab and saved to Google Drive as CSV, JSON, figures, and PKL.

# %%
# Install pinned runtime dependencies.
# !pip -q install ucimlrepo==0.0.7 xgboost==2.1.4 catboost==1.2.8 scikit-learn==1.6.1 pandas==2.2.2 numpy==2.0.2 matplotlib==3.10.0 joblib==1.4.2
print("✓ Dependencies installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 29.7 MB/s eta 0:00:00
# ✓ Dependencies installed

# %%
import hashlib
import urllib.request

LOADER_COMMIT = "1e700378834707918df3c5943a6a6703cd087e5d"
EXPECTED_LOADER_SHA256 = "e45375e141e9333cda8e742c8628bc4200cb94e8af2fa98909219a9d44d7b4f3"
LOADER_URL = (
    "https://raw.githubusercontent.com/AzizulHakim00/MAT-Appendix/"
    f"{LOADER_COMMIT}/src/v32_locked/verified_loader.py"
)

print("Loading checksum-pinned locked revalidation loader...")
loader_bytes = urllib.request.urlopen(LOADER_URL, timeout=180).read()
actual = hashlib.sha256(loader_bytes).hexdigest()
print("Loader commit:", LOADER_COMMIT)
print("Loader SHA256:", actual)
if actual != EXPECTED_LOADER_SHA256:
    raise RuntimeError(f"Loader checksum mismatch: expected {EXPECTED_LOADER_SHA256}, got {actual}")
exec(compile(loader_bytes.decode("utf-8"), LOADER_URL, "exec"), globals(), globals())
# Out:
# Loading checksum-pinned locked revalidation loader...
# Loader commit: 1e700378834707918df3c5943a6a6703cd087e5d
# Loader SHA256: e45375e141e9333cda8e742c8628bc4200cb94e8af2fa98909219a9d44d7b4f3
# Loading MAT-Appendix V3.2 Locked Revalidation...
# Pinned source commit: d56313c50767d4ed4067d4fefa909f9aaaba5ec7
#   core.py: sha256=1de44294ecbf755e81485f86013a3dd2c2cac7320a25204d27a3e481c4909e83 bytes=11559
#   models.py: sha256=a0798f161c3d5f4708ecd0428838f9cf39f0c2201736e3fcb50678cf11767bb5 bytes=8768
#   payload.txt: sha256=86d52e1d97a9f1f1e03f846f615eb73acb9e7ce7235f55f57225f725ff09107a bytes=14072
#   runner.py: sha256=b05f5e45e1398d05f34bf3fb012c3caf33ddca1b931471a600f983e685d3ded5 bytes=42432
# Source integrity and syntax verified.
# PRE-FLIGHT PASSED: calibration, thresholding, metrics and constrained blend.
# Drive unavailable; using /content: mount failed
# MAT-APPENDIX V3.2 LOCKED REVALIDATION | 1.0.0
# Validated cohort: 463 patients; 118 complicated
# ...
