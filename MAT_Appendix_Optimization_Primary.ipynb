# %% [markdown]
# # MAT-Appendix Nested Optimization
# Leakage-safe five-fold nested tuning and stacking for the corrected confirmed-appendicitis severity endpoint. Requested performance values are goals, not guaranteed outputs.
#
# **Hotfix 2026-08-01:** Random Forest and Extra Trees mixed-type parameter sampling corrected.

# %%
import urllib.request
url = 'https://raw.githubusercontent.com/AzizulHakim00/MAT-Appendix/main/src/v3/optimization_primary.py?hotfix=20260801'
source = urllib.request.urlopen(url).read().decode('utf-8')
exec(compile(source, url, 'exec'))
