# %% [markdown]
# # MAT-Appendix V3.3 Fresh Optimization
# Leakage-safe primary experiment with fold-safe stability selection, modality branches, compact MAT-V2, constrained blending, calibration, and resumable outer-fold checkpoints.

# %%
import urllib.request
import hashlib

SOURCE_COMMIT = "3358fccc950248819571f0e3c6d74d63438e34e1"

URL = (
    "https://raw.githubusercontent.com/"
    "AzizulHakim00/MAT-Appendix/"
    f"{SOURCE_COMMIT}/src/v33/"
    "mat_appendix_v33_fresh_pipeline.py"
)

EXPECTED_SHA256 = (
    "2b794486b43049762faabc52e6c492372"
    "1bb4cb050fa8018c75ee6a5a94b202e"
)

print("Loading MAT-Appendix V3.3 from pinned GitHub commit...")
print("Source commit:", SOURCE_COMMIT)

source = urllib.request.urlopen(URL).read().decode("utf-8")
actual = hashlib.sha256(source.encode("utf-8")).hexdigest()

if actual != EXPECTED_SHA256:
    raise RuntimeError(
        "V3.3 source checksum mismatch.\n"
        f"Expected: {EXPECTED_SHA256}\n"
        f"Actual:   {actual}"
    )

print("Source integrity verified.")

exec(
    compile(source, URL, "exec"),
    globals(),
    globals(),
)
# Out:
# Loading MAT-Appendix V3.3 from pinned GitHub commit...
# Source commit: 3358fccc950248819571f0e3c6d74d63438e34e1
# Source integrity verified.
# Mounted at /content/drive
# Device: cuda
# V3.3 targets are evaluation goals, never guaranteed settings.
# PRE-FLIGHT SELF-TEST PASSED: classical APIs, MAT-V2, thresholds and JSON.
#
# CORRECTED COHORT
# N=463, complicated=118, uncomplicated=345
# Features after engineering=58
#
# STRICT LEAKAGE AUDIT
#              Feature Action                                          Reason
#       Length_of_Stay   DROP identifier/target/post-decision/direct-endpoint
#          Peritonitis   DROP identifier/target/post-decision/direct-endpoint
#          Perforation   DROP identifier/target/post-decision/direct-endpoint
# Appendicular_Abscess   DROP identifier/target/post-decision/direct-endpoint
#     Abscess_Location   DROP identifier/target/post-decision/direct-endpoint
#
# ===== REPEAT 1/1, OUTER FOLD 1/5 =====
# ...

# %%
import urllib.request
import hashlib

SOURCE_COMMIT = "3358fccc950248819571f0e3c6d74d63438e34e1"

URL = (
    "https://raw.githubusercontent.com/"
    "AzizulHakim00/MAT-Appendix/"
    f"{SOURCE_COMMIT}/src/v33/"
    "mat_appendix_v33_fresh_pipeline.py"
)

EXPECTED_SHA256 = (
    "2b794486b43049762faabc52e6c492372"
    "1bb4cb050fa8018c75ee6a5a94b202e"
)

print("Loading MAT-Appendix V3.3 from pinned GitHub commit...")
print("Source commit:", SOURCE_COMMIT)

source = urllib.request.urlopen(URL).read().decode("utf-8")
actual = hashlib.sha256(source.encode("utf-8")).hexdigest()

if actual != EXPECTED_SHA256:
    raise RuntimeError(
        "V3.3 source checksum mismatch.\n"
        f"Expected: {EXPECTED_SHA256}\n"
        f"Actual:   {actual}"
    )

print("Source integrity verified.")

exec(
    compile(source, URL, "exec"),
    globals(),
    globals(),
)
# Out:
# Loading MAT-Appendix V3.3 from pinned GitHub commit...
# Source commit: 3358fccc950248819571f0e3c6d74d63438e34e1
# Source integrity verified.
# Mounted at /content/drive
# Device: cpu
# V3.3 targets are evaluation goals, never guaranteed settings.
# PRE-FLIGHT SELF-TEST PASSED: classical APIs, MAT-V2, thresholds and JSON.
#
# CORRECTED COHORT
# N=463, complicated=118, uncomplicated=345
# Features after engineering=58
#
# STRICT LEAKAGE AUDIT
#              Feature Action                                          Reason
#       Length_of_Stay   DROP identifier/target/post-decision/direct-endpoint
#          Peritonitis   DROP identifier/target/post-decision/direct-endpoint
#          Perforation   DROP identifier/target/post-decision/direct-endpoint
# Appendicular_Abscess   DROP identifier/target/post-decision/direct-endpoint
#     Abscess_Location   DROP identifier/target/post-decision/direct-endpoint
#
# ===== REPEAT 1/1, OUTER FOLD 1/5 =====
# Loading completed fold checkpoint.
# ...
