# %% [markdown]
# # MAT-Appendix Nested Optimization V3.1 Final
# Clean audited version with fail-fast self-tests, manual meta-CV, corrected leakage rules, raw-OOF stacking, and resumable outer-fold checkpoints.

# %%
import urllib.request
url = 'https://raw.githubusercontent.com/AzizulHakim00/MAT-Appendix/main/src/v3_1/optimization_primary_v31_final.py?v=20260801-final'
source = urllib.request.urlopen(url).read().decode("utf-8")
exec(compile(source, url, "exec"))
# Out:
# Loaded verified MAT-Appendix Optimization V3.1 final source.
# Google Drive unavailable; using /content: mount failed
# Device: cuda
# Run ID: 20260731T212349Z
# Output: /content/MAT-Appendix/optimization_runs/20260731T212349Z
# Important: requested performance targets are evaluation goals, not guaranteed settings.
#
# CORRECTED COHORT
#                          Item  \
# 0      Confirmed_appendicitis
# 1                 Complicated
# 2               Uncomplicated
# 3                  Prevalence
# 4  Features_after_engineering
# 5                      SHA256
#
#                                                Value
# 0                                                463
# 1                                                118
# 2                                                345
# 3                                            0.25486
# 4                                                 67
# 5  be63b616eae8ea58b4ef7e15e36ffe73eef5c65c5a60a6...
# STRICT LEAKAGE AUDIT: DROPPED FEATURES
#                 Feature Action  \
# 0        Length_of_Stay   DROP
# 1           Peritonitis   DROP
# 2           Perforation   DROP
# 3  Appendicular_Abscess   DROP
# 4      Abscess_Location   DROP
#
#                                             Reason
# 0  identifier/target/post-decision/direct-endpoint
# 1  identifier/target/post-decision/direct-endpoint
# 2  identifier/target/post-decision/direct-endpoint
# 3  identifier/target/post-decision/direct-endpoint
# 4  identifier/target/post-decision/direct-endpoint
# PRE-FLIGHT SELF-TEST PASSED: parameter types, all model APIs, cloning and production meta-CV.
#
# ===== OUTER FOLD 1/5 =====
# Tuning Logistic Regression
# Tuning Random Forest
# Tuning Extra Trees
# Tuning XGBoost
# Tuning CatBoost
# Training nested MAT-Appendix
# Tuning leakage-safe stacked meta-model
# Fold ensemble: {'Model': 'Optimized Stacked Ensemble', 'N': 93, 'Positive_N': 24, 'Accuracy': np.float64(0.7849462365591398), 'Error_Rate': np.float64(0.21505376344086025), 'Balanced_Accuracy': np.float64(0.7599637681159421), 'Precision_PPV': np.float64(0.5666666666666667), 'Recall_Sensitivity_TPR': np.float64(0.7083333333333334), 'Specificity_TNR': np.float64(0.8115942028985508), 'NPV': np.float64(0.8888888888888888), 'F1': 0.6296296296296297, 'F2': 0.6746031746031746, 'MCC': np.float64(0.4866784129348118), 'Cohens_Kappa': np.float64(0.4807370184254607), 'ROC_AUC': np.float64(0.8097826086956522), 'PR_AUC': np.float64(0.6383135154733025), 'Brier': np.float64(0.16146457809048617), 'Log_Loss': 0.5097955674397526, 'ECE': 0.11002566225024926, 'MCE': 0.873858242603717, 'FPR': np.float64(0.18840579710144928), 'FNR': np.float64(0.2916666666666667), 'TP': 17, 'TN': 56, 'FP': 13, 'FN': 7}
# Saved resumable checkpoint: /content/MAT-Appendix/optimization_checkpoints/v31_be63b616eae8ea58_ace3a53934e9d18e.pkl
#
# ===== OUTER FOLD 2/5 =====
# Tuning Logistic Regression
# Tuning Random Forest
# Tuning Extra Trees
# Tuning XGBoost
# Tuning CatBoost
# Training nested MAT-Appendix
# Tuning leakage-safe stacked meta-model
# Fold ensemble: {'Model': 'Optimized Stacked Ensemble', 'N': 93, 'Positive_N': 24, 'Accuracy': np.float64(0.8602150537634409), 'Error_Rate': np.float64(0.13978494623655913), 'Balanced_Accuracy': np.float64(0.8514492753623188), 'Precision_PPV': np.float64(0.6896551724137931), 'Recall_Sensitivity_TPR': np.float64(0.8333333333333334), 'Specificity_TNR': np.float64(0.8695652173913043), 'NPV': np.float64(0.9375), 'F1': 0.7547169811320755, 'F2': 0.8, 'MCC': np.float64(0.6639476348094897), 'Cohens_Kappa': np.float64(0.6581849024597116), 'ROC_AUC': np.float64(0.8979468599033816), 'PR_AUC': np.float64(0.7795451276207395), 'Brier': np.float64(0.10763733784736276), 'Log_Loss': 0.34267421006705695, 'ECE': 0.07312165679282423, 'MCE': 0.6436567211871544, 'FPR': np.float64(0.13043478260869565), 'FNR': np.float64(0.16666666666666666), 'TP': 20, 'TN': 60, 'FP': 9, 'FN': 4}
# Saved resumable checkpoint: /content/MAT-Appendix/optimization_checkpoints/v31_be63b616eae8ea58_ace3a53934e9d18e.pkl
#
# ===== OUTER FOLD 3/5 =====
# Tuning Logistic Regression
# Tuning Random Forest
# Tuning Extra Trees
# Tuning XGBoost
# Tuning CatBoost
# Training nested MAT-Appendix
# Tuning leakage-safe stacked meta-model
# Fold ensemble: {'Model': 'Optimized Stacked Ensemble', 'N': 93, 'Positive_N': 24, 'Accuracy': np.float64(0.7849462365591398), 'Error_Rate': np.float64(0.21505376344086025), 'Balanced_Accuracy': np.float64(0.7871376811594203), 'Precision_PPV': np.float64(0.5588235294117647), 'Recall_Sensitivity_TPR': np.float64(0.7916666666666666), 'Specificity_TNR': np.float64(0.782608695652174), 'NPV': np.float64(0.9152542372881356), 'F1': 0.6551724137931034, 'F2': 0.7307692307692307, 'MCC': np.float64(0.5217769458675728), 'Cohens_Kappa': np.float64(0.5055821371610845), 'ROC_AUC': np.float64(0.8725845410628019), 'PR_AUC': np.float64(0.700473448661871), 'Brier': np.float64(0.12673149543566792), 'Log_Loss': 0.39025139982442125, 'ECE': 0.07676749419966324, 'MCE': 0.5170515229457308, 'FPR': np.float64(0.21739130434782608), 'FNR': np.float64(0.20833333333333334), 'TP': 19, 'TN': 54, 'FP': 15, 'FN': 5}
# Saved resumable checkpoint: /content/MAT-Appendix/optimization_checkpoints/v31_be63b616eae8ea58_ace3a53934e9d18e.pkl
#
# ===== OUTER FOLD 4/5 =====
# Tuning Logistic Regression
# Tuning Random Forest
# Tuning Extra Trees
# Tuning XGBoost
# Tuning CatBoost
# Training nested MAT-Appendix
# Tuning leakage-safe stacked meta-model
# Fold ensemble: {'Model': 'Optimized Stacked Ensemble', 'N': 92, 'Positive_N': 23, 'Accuracy': np.float64(0.8369565217391305), 'Error_Rate': np.float64(0.1630434782608695), 'Balanced_Accuracy': np.float64(0.818840579710145), 'Precision_PPV': np.float64(0.6428571428571429), 'Recall_Sensitivity_TPR': np.float64(0.782608695652174), 'Specificity_TNR': np.float64(0.855072463768116), 'NPV': np.float64(0.921875), 'F1': 0.7058823529411765, 'F2': 0.75, 'MCC': np.float64(0.600099198148979), 'Cohens_Kappa': np.float64(0.5945945945945945), 'ROC_AUC': np.float64(0.9199747952110902), 'PR_AUC': np.float64(0.8087726967278264), 'Brier': np.float64(0.1024820629953447), 'Log_Loss': 0.32644115915593075, 'ECE': 0.07450593830450591, 'MCE': 0.4369755340764915, 'FPR': np.float64(0.14492753623188406), 'FNR': np.float64(0.21739130434782608), 'TP': 18, 'TN': 59, 'FP': 10, 'FN': 5}
# Saved resumable checkpoint: /content/MAT-Appendix/optimization_checkpoints/v31_be63b616eae8ea58_ace3a53934e9d18e.pkl
#
# ===== OUTER FOLD 5/5 =====
# Tuning Logistic Regression
# Tuning Random Forest
# Tuning Extra Trees
# Tuning XGBoost
# Tuning CatBoost
# Training nested MAT-Appendix
# Tuning leakage-safe stacked meta-model
# Fold ensemble: {'Model': 'Optimized Stacked Ensemble', 'N': 92, 'Positive_N': 23, 'Accuracy': np.float64(0.7717391304347826), 'Error_Rate': np.float64(0.2282608695652174), 'Balanced_Accuracy': np.float64(0.7753623188405797), 'Precision_PPV': np.float64(0.5294117647058824), 'Recall_Sensitivity_TPR': np.float64(0.782608695652174), 'Specificity_TNR': np.float64(0.7681159420289855), 'NPV': np.float64(0.9137931034482759), 'F1': 0.631578947368421, 'F2': 0.7142857142857143, 'MCC': np.float64(0.49404841911772657), 'Cohens_Kappa': np.float64(0.475), 'ROC_AUC': np.float64(0.9073724007561437), 'PR_AUC': np.float64(0.8247058433097134), 'Brier': np.float64(0.10159361513985957), 'Log_Loss': 0.3290320495207118, 'ECE': 0.0794995824623396, 'MCE': 0.5522784223455188, 'FPR': np.float64(0.2318840579710145), 'FNR': np.float64(0.21739130434782608), 'TP': 18, 'TN': 53, 'FP': 16, 'FN': 5}
# Saved resumable checkpoint: /content/MAT-Appendix/optimization_checkpoints/v31_be63b616eae8ea58_ace3a53934e9d18e.pkl
#
# FINAL COMPLETE METRICS
#                         Model    N  Positive_N  Accuracy  Error_Rate  \
# 0         Logistic Regression  463         118  0.790497    0.209503
# 1  Optimized Stacked Ensemble  463         118  0.807775    0.192225
# 2                    CatBoost  463         118  0.792657    0.207343
# 3                 Extra Trees  463         118  0.784017    0.215983
# 4                     XGBoost  463         118  0.818575    0.181425
# 5               Random Forest  463         118  0.809935    0.190065
# 6                MAT-Appendix  463         118  0.796976    0.203024
#
#    Balanced_Accuracy  Precision_PPV  Recall_Sensitivity_TPR  Specificity_TNR  \
# 0           0.792508       0.562874                0.796610         0.788406
# 1           0.798526       0.593548                0.779661         0.817391
# 2           0.807897       0.562500                0.838983         0.776812
# 3           0.785372       0.553571                0.788136         0.782609
# 4           0.814137       0.608974                0.805085         0.823188
# 5           0.822280       0.588235                0.847458         0.797101
# 6           0.788492       0.575949                0.771186         0.805797
#
#         NPV  ...     Brier  Log_Loss       ECE       MCE       FPR       FNR  \
# 0  0.918919  ...  0.120129  0.385364  0.051209  0.259875  0.211594  0.203390
# 1  0.915584  ...  0.120059  0.379863  0.037276  0.155697  0.182609  0.220339
# 2  0.933798  ...  0.120735  0.379339  0.053214  0.150565  0.223188  0.161017
# 3  0.915254  ...  0.123503  0.383532  0.026810  0.103675  0.217391  0.211864
# 4  0.925081  ...  0.124050  0.390524  0.057622  0.194378  0.176812  0.194915
# 5  0.938567  ...  0.122947  0.383617  0.049916  0.225189  0.202899  0.152542
# 6  0.911475  ...  0.137762  0.430486  0.052279  0.187176  0.194203  0.228814
#
#     TP   TN  FP  FN
# 0   94  272  73  24
# 1   92  282  63  26
# 2   99  268  77  19
# 3   93  270  75  25
# 4   95  284  61  23
# 5  100  275  70  18
# 6   91  278  67  27
#
# [7 rows x 26 columns]
# REQUESTED TARGET GAP
#                         Model                  Metric  Observed  \
# 4  Optimized Stacked Ensemble                 ROC_AUC  0.875854
# 5  Optimized Stacked Ensemble  Recall_Sensitivity_TPR  0.779661
# 6  Optimized Stacked Ensemble         Specificity_TNR  0.817391
# 7  Optimized Stacked Ensemble                Accuracy  0.807775
#
#    Requested_Target       Gap  Reached
# 4              0.95 -0.074146    False
# 5              0.95 -0.170339    False
# 6              0.95 -0.132609    False
# 7              0.97 -0.162225    False
# META-MODEL SELECTION
#    Outer_Fold      Selected_Meta_Model  Inner_Objective  Primary_Threshold  \
# 0           1  Logistic_C0.02_balanced         0.809785           0.228611
# 1           2              ConvexBlend         0.771278           0.241000
# 2           3              ConvexBlend         0.791796           0.235000
# 3           4  Logistic_C0.02_balanced         0.791259           0.212000
# 4           5              ConvexBlend         0.780534           0.218000
#
#    Joint_95_Feasible_In_Training  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#                                       Convex_Weights
# 0
# 1  [0.5938395476496637, 0.13062585830245785, 0.03...
# 2  [0.6079350057684807, 0.009742250179035688, 0.1...
# 3
# 4  [0.5578031120410625, 0.021871495987096246, 0.0...
# PAIRED BOOTSTRAP: ENSEMBLE VS BASES
#                      Reference           Comparator       Metric  \
# 0   Optimized Stacked Ensemble  Logistic Regression      ROC_AUC
# 1   Optimized Stacked Ensemble  Logistic Regression       PR_AUC
# 2   Optimized Stacked Ensemble  Logistic Regression        Brier
# 3   Optimized Stacked Ensemble  Logistic Regression     Accuracy
# 4   Optimized Stacked Ensemble  Logistic Regression  Sensitivity
# 5   Optimized Stacked Ensemble  Logistic Regression  Specificity
# 6   Optimized Stacked Ensemble  Logistic Regression          MCC
# 7   Optimized Stacked Ensemble        Random Forest      ROC_AUC
# 8   Optimized Stacked Ensemble        Random Forest       PR_AUC
# 9   Optimized Stacked Ensemble        Random Forest        Brier
# 10  Optimized Stacked Ensemble        Random Forest     Accuracy
# 11  Optimized Stacked Ensemble        Random Forest  Sensitivity
# 12  Optimized Stacked Ensemble        Random Forest  Specificity
# 13  Optimized Stacked Ensemble        Random Forest          MCC
# 14  Optimized Stacked Ensemble          Extra Trees      ROC_AUC
# 15  Optimized Stacked Ensemble          Extra Trees       PR_AUC
# 16  Optimized Stacked Ensemble          Extra Trees        Brier
# 17  Optimized Stacked Ensemble          Extra Trees     Accuracy
# 18  Optimized Stacked Ensemble          Extra Trees  Sensitivity
# 19  Optimized Stacked Ensemble          Extra Trees  Specificity
# 20  Optimized Stacked Ensemble          Extra Trees          MCC
# 21  Optimized Stacked Ensemble              XGBoost      ROC_AUC
# 22  Optimized Stacked Ensemble              XGBoost       PR_AUC
# 23  Optimized Stacked Ensemble              XGBoost        Brier
# 24  Optimized Stacked Ensemble              XGBoost     Accuracy
# 25  Optimized Stacked Ensemble              XGBoost  Sensitivity
# 26  Optimized Stacked Ensemble              XGBoost  Specificity
# 27  Optimized Stacked Ensemble              XGBoost          MCC
# 28  Optimized Stacked Ensemble             CatBoost      ROC_AUC
# 29  Optimized Stacked Ensemble             CatBoost       PR_AUC
# 30  Optimized Stacked Ensemble             CatBoost        Brier
# 31  Optimized Stacked Ensemble             CatBoost     Accuracy
# 32  Optimized Stacked Ensemble             CatBoost  Sensitivity
# 33  Optimized Stacked Ensemble             CatBoost  Specificity
# 34  Optimized Stacked Ensemble             CatBoost          MCC
# 35  Optimized Stacked Ensemble         MAT-Appendix      ROC_AUC
# 36  Optimized Stacked Ensemble         MAT-Appendix       PR_AUC
# 37  Optimized Stacked Ensemble         MAT-Appendix        Brier
# 38  Optimized Stacked Ensemble         MAT-Appendix     Accuracy
# 39  Optimized Stacked Ensemble         MAT-Appendix  Sensitivity
# 40  Optimized Stacked Ensemble         MAT-Appendix  Specificity
# 41  Optimized Stacked Ensemble         MAT-Appendix          MCC
#
#     Difference_Favoring_Reference   CI_2.5%  CI_97.5%  Two_Sided_P
# 0                        0.010925 -0.001959  0.025952        0.114
# 1                       -0.013215 -0.052441  0.022492        0.504
# 2                        0.000060 -0.006309  0.006225        0.971
# 3                        0.016940 -0.004320  0.041037        0.157
# 4                       -0.017052 -0.053571  0.015385        0.432
# 5                        0.029352  0.002841  0.056497        0.041
# 6                        0.020107 -0.022074  0.062277        0.373
# 7                        0.003196 -0.011472  0.016607        0.628
# 8                        0.054175  0.018253  0.093565        0.004
# 9                        0.002940 -0.004342  0.009957        0.382
# 10                      -0.001875 -0.030238  0.025918        0.966
# 11                      -0.067531 -0.125984 -0.009896        0.022
# 12                       0.021086 -0.011053  0.053372        0.231
# 13                      -0.031249 -0.091237  0.028807        0.294
# 14                       0.008120 -0.008295  0.024996        0.365
# 15                       0.013962 -0.032252  0.057677        0.531
# 16                       0.003447 -0.006755  0.013260        0.499
# 17                       0.023460 -0.004320  0.051836        0.126
# 18                      -0.009439 -0.073786  0.053109        0.883
# 19                       0.034461  0.002824  0.065869        0.043
# 20                       0.032086 -0.030052  0.100535        0.343
# 21                       0.008735 -0.006847  0.024779        0.274
# 22                       0.041707  0.002861  0.082064        0.036
# 23                       0.003931 -0.004059  0.011603        0.322
# 24                      -0.010778 -0.036717  0.015119        0.461
# 25                      -0.025572 -0.075000  0.020441        0.391
# 26                      -0.006777 -0.036478  0.023121        0.740
# 27                      -0.027769 -0.082389  0.028792        0.326
# 28                       0.001509 -0.016204  0.018733        0.851
# 29                       0.013225 -0.029006  0.056908        0.546
# 30                       0.000734 -0.009258  0.010346        0.898
# 31                       0.015243 -0.015119  0.047516        0.360
# 32                      -0.058854 -0.133346  0.008407        0.105
# 33                       0.040673  0.005797  0.075631        0.025
# 34                      -0.001616 -0.068038  0.064070        0.970
# 35                       0.043882  0.012662  0.076039        0.005
# 36                       0.085580  0.021281  0.151655        0.001
# 37                       0.017858  0.002558  0.032186        0.027
# 38                       0.010734 -0.023758  0.043197        0.563
# 39                       0.008721 -0.066667  0.088242        0.912
# 40                       0.011548 -0.021153  0.046581        0.566
# 41                       0.021987 -0.054952  0.095692        0.568
# GitHub export: {'status': 'skipped', 'reason': 'GITHUB_TOKEN missing; Drive artifacts are complete and no retraining is needed.'}
# Reproducibility PKL: /content/MAT-Appendix/optimization_runs/20260731T212349Z/mat_appendix_optimized_v31_reproducibility.pkl
#
# SCIENTIFIC VERDICT
# One or more requested targets were not reached. Do not alter the outer-test results or add target-derived features to force them.
# Removed completed-run checkpoint: /content/MAT-Appendix/optimization_checkpoints/v31_be63b616eae8ea58_ace3a53934e9d18e.pkl
# DONE: V3.1 tuning, calibration, stacking and thresholds were nested inside outer-training data.
