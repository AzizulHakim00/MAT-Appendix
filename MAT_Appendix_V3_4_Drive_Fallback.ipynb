# %% [markdown]
# <a href="https://colab.research.google.com/github/AzizulHakim00/MAT-Appendix/blob/main/MAT_Appendix_V3_4_Drive_Fallback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MAT-Appendix V3.4 — Drive-Fallback Run
# Runs the pinned, verified V3.4 challenge source. If Google Drive mounting fails, execution continues safely under `/content`.

# %%
# MAT-APPENDIX V3.4 — ONE-CELL DRIVE-FALLBACK RUNNER
# No local upload or download is required.

import urllib.request

HOTFIX_COMMIT = "7bf062082d575125114d4da4ba6758a1904d474c"
URL = (
    "https://raw.githubusercontent.com/"
    "AzizulHakim00/MAT-Appendix/"
    f"{HOTFIX_COMMIT}/src/v34/"
    "mat_appendix_v34_drive_fallback_loader.py"
)

print("Loading MAT-Appendix V3.4 Drive-fallback runner...")
print("Pinned hotfix commit:", HOTFIX_COMMIT)

loader = urllib.request.urlopen(URL).read().decode("utf-8")
exec(compile(loader, URL, "exec"), globals(), globals())
# Out:
# Loading MAT-Appendix V3.4 Drive-fallback runner...
# Pinned hotfix commit: 7bf062082d575125114d4da4ba6758a1904d474c
# Loading verified MAT-Appendix V3.4 source with Drive fallback...
# Source ref: 86171faaaa47e3df939754420a3b71bcfe233073
# Original V3.4 source integrity verified.
# Drive fallback patch verified: 1 operational call patched.
# Mounted at /content/drive
#
# MAT-APPENDIX V3.4 — 0.93 AUROC CHALLENGE
# Requested target is evaluated only after all outer-test predictions are complete.
# Validated cohort: N=463, positives=118, negatives=345
# Predictor columns after engineering: 75
# Output: /content/drive/MyDrive/MAT-Appendix/v34_runs/v34_8c4d77214ca4c8
#
# ===== REPEAT 1/2, OUTER FOLD 1/5 =====
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.12.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Apr 30 18:17:14 UTC 2026
# ...
