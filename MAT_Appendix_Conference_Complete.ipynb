# %% [markdown]
# # MAT-Appendix Conference-Complete Run
# Confirmed appendicitis-only severity cohort. Runs five classical baselines, FT-Transformer, missingness ablation and MAT-Appendix on identical five OOF folds; produces complete metrics, calibration, XAI, subgroup analyses, PKL and GitHub paper assets.

# %%
import requests
BASE='https://raw.githubusercontent.com/AzizulHakim00/MAT-Appendix/main/src/v2'
part_names=[f'part_{i:02d}.pyfrag' for i in range(1,7)]+['part_07_pre.pyfrag','part_07b.pyfrag','part_07_post.pyfrag','part_08.pyfrag']
parts=[]
for name in part_names:
    url=f'{BASE}/{name}'
    response=requests.get(url,timeout=60)
    response.raise_for_status()
    parts.append(response.text)
source=''.join(parts)
compile(source,'MAT_Appendix_Conference_Complete','exec')
exec(source,globals())
# Out:
# Mounted at /content/drive
# Device: cuda
# Run ID: 20260731T181229Z
# Output: /content/drive/MyDrive/MAT-Appendix/runs/20260731T181229Z
#                           item  \
# 0  confirmed_appendicitis_rows
# 1                  complicated
# 2                uncomplicated
# 3                   prevalence
# 4                     features
# 5                       sha256
#
#                                                value
# 0                                                463
# 1                                                118
# 2                                                345
# 3                                            0.25486
# 4                                                 46
# 5  d3c160bfcabc86936f02dc927b379e4eaa6f52a32a006e...
#                     feature action                           reason
# 0            Length_of_Stay   DROP  identifier/target/post-decision
# 1               Peritonitis   DROP   direct_complication_definition
# 2              US_Performed   DROP   direct_complication_definition
# 3               Perforation   DROP   direct_complication_definition
# 4      Appendicular_Abscess   DROP   direct_complication_definition
# 5          Abscess_Location   DROP   direct_complication_definition
# 6  Pathological_Lymph_Nodes   DROP           procedure_or_pathology
# ===== OUTER FOLD 1/5 =====
# Logistic Regression PR-AUC= 0.616
# Random Forest PR-AUC= 0.5995
# XGBoost PR-AUC= 0.581
# CatBoost PR-AUC= 0.5998
# HistGradientBoosting PR-AUC= 0.5704
# Training FT-Transformer
# FT-Transformer PR-AUC= 0.7001
# Training MAT-NoMissingEmbedding
# MAT-NoMissingEmbedding PR-AUC= 0.593
# Training MAT-Appendix
# MAT-Appendix PR-AUC= 0.673
#
# ===== OUTER FOLD 2/5 =====
# Logistic Regression PR-AUC= 0.6974
# Random Forest PR-AUC= 0.6794
# XGBoost PR-AUC= 0.7248
# CatBoost PR-AUC= 0.7718
# HistGradientBoosting PR-AUC= 0.653
# Training FT-Transformer
# FT-Transformer PR-AUC= 0.778
# Training MAT-NoMissingEmbedding
# MAT-NoMissingEmbedding PR-AUC= 0.8052
# Training MAT-Appendix
# MAT-Appendix PR-AUC= 0.8046
#
# ===== OUTER FOLD 3/5 =====
# Logistic Regression PR-AUC= 0.6823
# Random Forest PR-AUC= 0.6785
# XGBoost PR-AUC= 0.7221
# CatBoost PR-AUC= 0.6791
# HistGradientBoosting PR-AUC= 0.6771
# Training FT-Transformer
# FT-Transformer PR-AUC= 0.6492
# Training MAT-NoMissingEmbedding
# MAT-NoMissingEmbedding PR-AUC= 0.6448
# Training MAT-Appendix
# MAT-Appendix PR-AUC= 0.6707
#
# ===== OUTER FOLD 4/5 =====
# Logistic Regression PR-AUC= 0.7221
# Random Forest PR-AUC= 0.7829
# XGBoost PR-AUC= 0.7718
# CatBoost PR-AUC= 0.7607
# HistGradientBoosting PR-AUC= 0.7586
# Training FT-Transformer
# FT-Transformer PR-AUC= 0.7648
# Training MAT-NoMissingEmbedding
# MAT-NoMissingEmbedding PR-AUC= 0.7678
# Training MAT-Appendix
# MAT-Appendix PR-AUC= 0.7319
#
# ===== OUTER FOLD 5/5 =====
# Logistic Regression PR-AUC= 0.8048
# Random Forest PR-AUC= 0.7797
# XGBoost PR-AUC= 0.7214
# CatBoost PR-AUC= 0.7087
# HistGradientBoosting PR-AUC= 0.694
# Training FT-Transformer
# FT-Transformer PR-AUC= 0.66
# Training MAT-NoMissingEmbedding
# MAT-NoMissingEmbedding PR-AUC= 0.7413
# Training MAT-Appendix
# MAT-Appendix PR-AUC= 0.6392
#   0%|          | 0/30 [00:00<?, ?it/s]
# PRIMARY COMPLETE METRIC TABLE
#                     Model                                       Probability  \
# 0           Random Forest  cross-fitted calibrated + cross-fitted threshold
# 1                CatBoost  cross-fitted calibrated + cross-fitted threshold
# 2     Logistic Regression  cross-fitted calibrated + cross-fitted threshold
# 3                 XGBoost  cross-fitted calibrated + cross-fitted threshold
# 4  MAT-NoMissingEmbedding  cross-fitted calibrated + cross-fitted threshold
# 5            MAT-Appendix  cross-fitted calibrated + cross-fitted threshold
# 6    HistGradientBoosting  cross-fitted calibrated + cross-fitted threshold
# 7          FT-Transformer  cross-fitted calibrated + cross-fitted threshold
#
#      N  Positive_N  Prevalence  Accuracy  Error_Rate  Balanced_Accuracy  \
# 0  463         118     0.25486  0.775378    0.224622           0.807455
# 1  463         118     0.25486  0.732181    0.267819           0.761742
# 2  463         118     0.25486  0.753780    0.246220           0.751142
# 3  463         118     0.25486  0.755940    0.244060           0.766532
# 4  463         118     0.25486  0.781857    0.218143           0.775559
# 5  463         118     0.25486  0.786177    0.213823           0.797973
# 6  463         118     0.25486  0.766739    0.233261           0.762626
# 7  463         118     0.25486  0.794816    0.205184           0.761950
#
#    Precision_PPV  Recall_Sensitivity_TPR  ...     Brier  Log_Loss       ECE  \
# 0       0.536458                0.872881  ...  0.123458  0.387428  0.048671
# 1       0.485000                0.822034  ...  0.128122  0.398244  0.037110
# 2       0.511628                0.745763  ...  0.130552  0.421898  0.022960
# 3       0.513812                0.788136  ...  0.127225  0.396578  0.021009
# 4       0.552147                0.762712  ...  0.128093  0.396260  0.023182
# 5       0.554286                0.822034  ...  0.129690  0.411293  0.064739
# 6       0.529762                0.754237  ...  0.134504  0.413579  0.032064
# 7       0.581560                0.694915  ...  0.142143  0.446139  0.062280
#
#         MCE       FPR       FNR   TP   TN   FP  FN
# 0  0.200828  0.257971  0.127119  103  256   89  15
# 1  0.109956  0.298551  0.177966   97  242  103  21
# 2  0.127094  0.243478  0.254237   88  261   84  30
# 3  0.099394  0.255072  0.211864   93  257   88  25
# 4  0.100054  0.211594  0.237288   90  272   73  28
# 5  0.183752  0.226087  0.177966   97  267   78  21
# 6  0.154687  0.228986  0.245763   89  266   79  29
# 7  0.196539  0.171014  0.305085   82  286   59  36
#
# [8 rows x 28 columns]
# HIGH-SENSITIVITY OPERATING POINTS
#           Model        Probability    N  Positive_N  Prevalence  Accuracy  \
# 0  MAT-Appendix  balanced_accuracy  463         118     0.25486  0.786177
# 1  MAT-Appendix     sensitivity_90  463         118     0.25486  0.643629
# 2  MAT-Appendix     sensitivity_95  463         118     0.25486  0.572354
#
#    Error_Rate  Balanced_Accuracy  Precision_PPV  Recall_Sensitivity_TPR  ...  \
# 0    0.213823           0.797973       0.554286                0.822034  ...
# 1    0.356371           0.730201       0.409962                0.906780  ...
# 2    0.427646           0.696315       0.368421                0.949153  ...
#
#         ECE       MCE       FPR       FNR   TP   TN   FP  FN  \
# 0  0.064739  0.183752  0.226087  0.177966   97  267   78  21
# 1  0.064739  0.183752  0.446377  0.093220  107  191  154  11
# 2  0.064739  0.183752  0.556522  0.050847  112  153  192   6
#
#    Mean_Crossfit_Threshold  Deployment_Threshold_All_OOF
# 0                 0.202770                      0.201463
# 1                 0.129914                      0.126889
# 2                 0.095504                      0.092864
#
# [3 rows x 30 columns]
# PAIRED BOOTSTRAP COMPARISON
#                 Baseline  Strongest_Baseline   Metric  \
# 0    Logistic Regression               False  ROC_AUC
# 1    Logistic Regression               False   PR_AUC
# 2    Logistic Regression               False    Brier
# 3          Random Forest                True  ROC_AUC
# 4          Random Forest                True   PR_AUC
# 5          Random Forest                True    Brier
# 6                XGBoost               False  ROC_AUC
# 7                XGBoost               False   PR_AUC
# 8                XGBoost               False    Brier
# 9               CatBoost               False  ROC_AUC
# 10              CatBoost               False   PR_AUC
# 11              CatBoost               False    Brier
# 12  HistGradientBoosting               False  ROC_AUC
# 13  HistGradientBoosting               False   PR_AUC
# 14  HistGradientBoosting               False    Brier
# 15        FT-Transformer               False  ROC_AUC
# 16        FT-Transformer               False   PR_AUC
# 17        FT-Transformer               False    Brier
#
#     Difference_Favoring_MAT   CI_2.5%  CI_97.5%  Paired_Bootstrap_p
# 0                  0.010903 -0.023794  0.049129               0.622
# 1                 -0.024943 -0.095639  0.047898               0.512
# 2                  0.000745 -0.013997  0.015160               0.924
# 3                 -0.018473 -0.045829  0.006721               0.164
# 4                 -0.025979 -0.094717  0.049549               0.430
# 5                 -0.006268 -0.019460  0.007126               0.362
# 6                 -0.007388 -0.039846  0.024232               0.690
# 7                 -0.016168 -0.090910  0.066417               0.664
# 8                 -0.002425 -0.017784  0.012520               0.766
# 9                 -0.008604 -0.036784  0.021969               0.534
# 10                -0.021307 -0.086700  0.045042               0.504
# 11                -0.001876 -0.014333  0.011687               0.772
# 12                 0.005361 -0.027901  0.039995               0.756
# 13                 0.014487 -0.062698  0.100970               0.718
# 14                 0.004846 -0.010652  0.020969               0.552
# 15                 0.032666 -0.003755  0.071966               0.100
# 16                 0.037162 -0.047512  0.115418               0.356
# 17                 0.012579 -0.001494  0.027182               0.082
# SUBGROUP RESULTS
#       Subgroup   Level    N  Positive_N  Prevalence   ROC_AUC    PR_AUC  \
# 0          Age   10-13  204          43    0.210784  0.846165  0.626102
# 1          Age     <10  160          53    0.331250  0.853465  0.708988
# 2          Age    >=14   99          22    0.222222  0.815230  0.609150
# 3          Sex  female  200          55    0.275000  0.867085  0.764695
# 4          Sex    male  262          63    0.240458  0.840711  0.592251
# 5  Missingness    High  155          66    0.425806  0.780729  0.689007
# 6  Missingness     Low  154          34    0.220779  0.813235  0.703958
# 7  Missingness  Medium  154          18    0.116883  0.905229  0.503290
#
#    Accuracy  Balanced_Accuracy  Recall_Sensitivity_TPR  Specificity_TNR  \
# 0  0.803922           0.764986                0.697674         0.832298
# 1  0.756250           0.798713                0.924528         0.672897
# 2  0.797980           0.805195                0.818182         0.792208
# 3  0.775000           0.788401                0.818182         0.758621
# 4  0.797710           0.807171                0.825397         0.788945
# 5  0.696774           0.718335                0.863636         0.573034
# 6  0.818182           0.777941                0.705882         0.850000
# 7  0.844156           0.863562                0.888889         0.838235
#
#    Precision_PPV       NPV        F1       MCC     Brier       ECE
# 0       0.526316  0.911565  0.600000  0.481731  0.112628  0.035296
# 1       0.583333  0.947368  0.715328  0.563076  0.150408  0.122796
# 2       0.529412  0.938462  0.642857  0.534402  0.131365  0.097097
# 3       0.562500  0.916667  0.666667  0.525723  0.124416  0.071645
# 4       0.553191  0.934524  0.662420  0.547379  0.133578  0.086711
# 5       0.600000  0.850000  0.708075  0.443285  0.194317  0.091681
# 6       0.571429  0.910714  0.631579  0.517701  0.111423  0.080538
# 7       0.421053  0.982759  0.571429  0.541868  0.082911  0.102884
# XAI STATUS
#         SHAP       LIME
# 0  completed  completed
# Reproducibility bundle: /content/drive/MyDrive/MAT-Appendix/runs/20260731T181229Z/mat_appendix_complete_reproducibility.pkl
# GitHub export: {'status': 'skipped', 'reason': 'GITHUB_TOKEN missing. Add it to Colab Secrets and rerun only the GitHub export block; model retraining is not required.'}
# DONE. MAT-Appendix was trained exactly once in each of five OOF folds.
