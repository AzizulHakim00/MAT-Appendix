# %% [markdown]
# # MAT-Appendix Primary 5-Fold OOF Experiment
# Run the single cell below in Google Colab. Add a Colab secret named `GITHUB_TOKEN` with Contents read/write permission if you want results committed automatically.

# %%
import requests
BASE='https://raw.githubusercontent.com/AzizulHakim00/MAT-Appendix/main/src'
parts=[]
for name in ['part_01.pyfrag','part_02.pyfrag','part_03.pyfrag']:
    r=requests.get(f'{BASE}/{name}',timeout=60)
    r.raise_for_status()
    parts.append(r.text)
code=''.join(parts)
exec(compile(code,'MAT_Appendix_Colab.py','exec'))
# Out:
# Mounted at /content/drive
# Device: cuda Run: 20260731T165947Z Output: /content/drive/MyDrive/MAT-Appendix/runs/20260731T165947Z
#             item                                              value
# 0           rows                                                781
# 1    complicated                                                119
# 2  uncomplicated                                                662
# 3     prevalence                                           0.152369
# 4       features                                                 46
# 5         sha256  ef6ad74ca0807ded4a23ea11eff3a87832aab14fe06a5f...
#                      feature action                           reason
# 5             Length_of_Stay   DROP  identifier/target/post-decision
# 31               Peritonitis   DROP         direct_target_definition
# 34              US_Performed   DROP         direct_target_definition
# 40               Perforation   DROP         direct_target_definition
# ...
